# %%
import pandas as pd
import numpy as np
import requests
import pyautogui
import datetime
import time

# %%
def check_internet(link):
    try :
        response = requests.get(link)
        return True
    except :
        return False

# %%
pyautogui.FAILSAFE = False
now = datetime.datetime.now().time()
num = now.minute
Rtime = list()
RiStatus = list ()
RDate  = list()

# %%
while True :
    #time.sleep(55)
    now = datetime.datetime.now().time()
    today = str (datetime.datetime.now().date().day) + '/'+str(datetime.datetime.now().date().month)+'/' + '2023'
    
 #   if check_internet :
 #       print('internet Available')
  #  else :
   #     print('internet not Available')
    
    if now.hour == 18 and now.minute == 32 :
        print('time up')
        break
    else :
        print (now.hour, now.minute,)
        pyautogui.doubleClick(200,500)
    if now.minute % 1 == 0:
        time.sleep(5)
        nowtime = str(now.hour)+ ' : ' + str(now.minute)
        
        Rtime.append(nowtime)
        if check_internet('https://www.linkedin.com/') :
            RDate.append(today)
            RiStatus.append('Working')
            print(nowtime,'- internet Available')
        else :
            print(nowtime,'- Internet Not available')
            RiStatus.append('NA')
            RDate.append(today)
        
  #  for i in range(500,600):
   #     pyautogui.moveTo(i,i)
# Out:
# 9 19
# 9 : 19 - internet Available
# 9 19
# 9 : 19 - internet Available
# 9 19
# 9 : 19 - internet Available
# 9 19
# 9 : 19 - internet Available
# 9 20
# 9 : 20 - internet Available
# 9 20
# 9 : 20 - internet Available
# 9 20
# 9 : 20 - internet Available
# 9 20
# 9 : 20 - internet Available
# 9 20
# 9 : 20 - internet Available
# 9 20
# 9 : 20 - internet Available
# 9 20
# 9 : 20 - internet Available
# 9 20
# 9 : 20 - internet Available
# 9 20
# 9 : 20 - internet Available
# 9 20
# 9 : 20 - internet Available
# 9 21
# 9 : 21 - internet Available
# 9 21
# 9 : 21 - internet Available
# 9 21
# 9 : 21 - internet Available
# 9 21
# 9 : 21 - internet Available
# 9 21
# 9 : 21 - internet Available
# 9 21
# 9 : 21 - internet Available
# 9 21
# 9 : 21 - internet Available
# 9 21
# 9 : 21 - internet Available
# 9 21
# 9 : 21 - internet Available
# 9 21
# 9 : 21 - internet Available
# 9 22
# 9 : 22 - internet Available
# 9 22
# 9 : 22 - internet Available
# 9 22
# 9 : 22 - internet Available
# ...

# %%
df = pd.DataFrame()
df ['Date ']=RDate
df ['Time ']=Rtime
df ['Internet Status'] = RiStatus
df
# Out:
#          Date    Time  Internet Status
# 0    15/3/2023  8 : 58         Working
# 1    15/3/2023  8 : 58         Working
# 2    15/3/2023  8 : 58         Working
# 3    15/3/2023  8 : 58         Working
# 4    15/3/2023  8 : 58         Working
# ..         ...     ...             ...
# 204  15/3/2023  9 : 18         Working
# 205  15/3/2023  9 : 18         Working
# 206  15/3/2023  9 : 18         Working
# 207  15/3/2023  9 : 18         Working
# 208  15/3/2023  9 : 18         Working
#
# [209 rows x 3 columns]

# %%
time.sleep(15)
pyautogui.doubleClick(200,500)

# %%
date = datetime.datetime.now().date()
date('https://www.linkedin.com/')

# %%
if check_internet('https://www.linkedin.com/') :
            print('internet Available')

# %%
import tensorflow

# %%
import nltk
nltk.download()

# %%
df.DataF

# %%
df.to_excel('out.xlsx')
